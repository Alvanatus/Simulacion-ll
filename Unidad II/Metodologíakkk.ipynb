# %% [markdown]
# # Metodología de la Simulación

# %% [markdown]
# ### 1. Identifique las variables
#
# Aquellas cuyo comportamiento define el comportamiento o la evoución global del sistema real.

# %% [markdown]
# ### 2. Determine la distribución de probabilidad
#
# Elija el tipo de distribución de probabilidad que mejor defina el comportamiento aleatorio de cada una de las variables del sistema identificadas en el paso anterior.

# %% [markdown]
# ### 3. Modele las variables aleatorias
#
# Cosntruya un modelo fiel de la aleatoriedad de las variables del sistema. Simular el comportamiento del sistema implica generar muestras aleatorias de cada variable que sigan fielmente la distribución de probabilidad correspondiente.

# %% [markdown]
# ### 4. Defina el modelo del sistema y los objetivos de la simulación
#
# Fije los objetivos y diseñe un modelo del sistema real que abstraiga sus propiedades más relevantes. Todo error en el modelo (o su implementación computacional) puede dar lugar a conclusiones equivocadas.
#
# Antes de experimentar con el modelo, asegurarse de que refleja fielmente el sistema real **validando** el mismo a partir de datos reales, para ello compare los resultados obtenidos de la simulación con los producidos por el sistema.

# %% [markdown]
# ### 5. Diseñe el experimento
#
# Diseñe un experimento así como las ejecuciones concretas del mismo, los escenarios que desea estudiar para alcanzar los objetivos fijados. El experimento consiste en generar valores de las variables cuyo comportamiento define el comportamiento del sistema y analizar este ante dichos valores.

# %% [markdown]
# ### 6. Repita el experimento $n$ veces
#
# Así dispondrá de $n$ observaciones sobre el comportamiento del sistema, lo que permitirá entender su funcionamiento así como evaluar el desempeño del mismo frente a los diversos escenarios establecidos.
#
# El **método Monte Carlo** se basa en la **Ley Fuerte de los Grandes Números** y el **Teorema del Límite Central**.

# %% [markdown]
# ## Ejemplo
#
# Calcule la probabilidad de que aparezcan dos caras lanzando tres veces una moneda al aire.
#
# 1. Analíticamente.
# 2. Mediante simulación.

# %% [markdown]
# Analiticamente:

# %% [markdown]
# Por simulación: Construimos el modelo en varios pasos.

# %% [markdown]
# **PASO 1**. Defina las variables que intervienen en el modelo.

# %%
x = x

# %% [markdown]
# **PASO 2**. Formule la distribución de probabilidad de cada variable.

# %% [markdown]
# |      |**Sol**|**Aguila**|
# |------|-------|----------|
# |f(x)|         |          |

# %% [markdown]
# **PASO 3**. Enumere la distribución acumulada de probabilidad de cada variable.

# %% [markdown]
# |      |**Sol**|**Aguila**|
# |------|-------|----------|
# |f(x)  |       |          |
# |F(x)  |       |          |

# %% [markdown]
# **PASO 4**. Establezca el intervalo de números aleatorios correspondiente a cada valor de cada una de las variables.

# %% [markdown]
# |           |**Sol**|**Aguila**|
# |-----------|-------|----------|
# |f(x)       |       |          |
# |F(x)       |       |          |
# |Intervalos |       |          |

# %% [markdown]
# **PASO 5**. Genere números aleatorios.

# %% [markdown]
# **PASO 6**. Simule un lanzamiento.

# %% [markdown]
# Si Número de caras = 2
#
# ¿Aparecen dos caras? = **1**
#
# Si Número de caras ≠ 2
#
# ¿Aparecen dos caras? = **0**

# %% [markdown]
# **PASO 7**. Obtenga la gráfica de estabilización que indica que el tamaño de muestra utilizado es suficiente para
# garantizar la convergencia del resultado.

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
def volados(n):
    caras = 0
    for i in range(n):
        u = random.uniform(0,1)
        if u <= 0.5:
            caras += 1
    return caras

# %%
def caras(m):
    favorable = 0
    if volados(3) == m:
        favorable +=1
    return favorable

# %%
def experimento(iteraciones):
    i = 0
    favorables=0
    Lista = []
    while i <= iteraciones:
        favorables = favorables + caras(2)
        i += 1
        probabilidad = favorables/i
        Lista.append(probabilidad)
    return Lista

# %%
exp = experimento(2000)

# %%
np.mean(exp)

# %%
plt.plot(exp)
plt.xlabel('iteraciones')
plt.ylabel('p')
plt.title('Probabilidad de obtener 2 caras')
plt.show()

# %% [markdown]
# **PASO 8**. Replique el modelo.

# %%
def simulacion_caras(repeticiones):
    List = []
    for i in range(repeticiones):
        List.append(np.mean(experimento(1000)))
    return List

# %%
simulacion = simulacion_caras(50)

# %%
plt.hist(simulacion)
plt.xlabel('iteraciones')
plt.ylabel('p')
plt.title('Probabilidad')
plt.show()

# %% [markdown]
# **PASO 9**. Calcule la probabilidad de que aparezcan dos caras lanzando tres veces una moneda al aire y su desviación
# estándar.

# %%
np.mean(simulacion), np.var(simulacion), np.std(simulacion)

# %% [markdown]
# **PASO 10**. Halle el intervalo de confianza de la probabilidad de queaparezcan dos caras lanzando tres veces una moneda
# al aire con un nivel de confianza del $95 \%$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Función a integrar
def integrand(x):
    return x / (1 + x**2)**2

# Función para generar muestras aleatorias de x con distribución exponencial truncada
def generar_muestras(n):
    # Generar muestras de una distribución exponencial
    muestras_exp = np.random.exponential(scale=1, size=n)
    # Truncar las muestras para asegurarse de que estén en el rango [0, inf)
    muestras_truncadas = muestras_exp[muestras_exp > 0]
    return muestras_truncadas

# Función para calcular la integral aproximada utilizando Monte Carlo
def monte_carlo_integral(n):
    muestras = generar_muestras(n)
    integral_aproximada = np.mean(integrand(muestras))
    return integral_aproximada

# Repetir el experimento n veces
def experimento_monte_carlo(repeticiones, muestras_por_repeticion):
    resultados = []
    for _ in range(repeticiones):
        integral_aproximada = monte_carlo_integral(muestras_por_repeticion)
        resultados.append(integral_aproximada)
    return resultados

# Realizar el experimento Monte Carlo
repeticiones = 1000
muestras_por_repeticion = 10000
resultados_experimento = experimento_monte_carlo(repeticiones, muestras_por_repeticion)

# Calcular la probabilidad y su desviación estándar
probabilidad_media = np.mean(resultados_experimento)
desviacion_estandar = np.std(resultados_experimento)

# Calcular intervalo de confianza al 95%
intervalo_confianza = 1.96 * desviacion_estandar / np.sqrt(repeticiones)
limite_inferior = probabilidad_media - intervalo_confianza
limite_superior = probabilidad_media + intervalo_confianza

print("Probabilidad estimada:", probabilidad_media)
print("Desviación estándar:", desviacion_estandar)
print("Intervalo de confianza al 95%:", (limite_inferior, limite_superior))

# Gráfico de estabilización
plt.plot(resultados_experimento)
plt.xlabel('Experimento')
plt.ylabel('Integral Aproximada')
plt.title('Convergencia de la integral mediante Monte Carlo')
plt.show()

# Histograma de los resultados
plt.hist(resultados_experimento, bins=30, edgecolor='black')
plt.xlabel('Integral Aproximada')
plt.ylabel('Frecuencia')
plt.title('Histograma de resultados')
plt.show()
# Out:
# Probabilidad estimada: 0.18923684414398423
# Desviación estándar: 0.001017304224327193
# Intervalo de confianza al 95%: (0.1891737909749094, 0.18929989731305905)

# %%
import sympy as sp

# Definir la variable y la función
x = sp.Symbol('x')
f = x / (1 + x**2)**2

# Paso 1: Realizar el cambio de variable
u = 1 + x**2

# Paso 2: Calcular du en términos de dx
du_dx = sp.diff(u, x)

# Paso 3: Expresar los límites de integración en términos de u
a = 1 + 0**2  # Límite inferior en términos de u
b = 1 + 1**2  # Límite superior en términos de u

# Paso 4: Calcular la integral resultante en términos de u
f_u = f.subs(x, sp.sqrt(u - 1)) * du_dx
integral_u = sp.integrate(f_u, (u, a, b))

# Paso 5: Revertir el cambio de variable para obtener el resultado en términos de x
resultado = integral_u.subs(u, 1 + x**2)

print("El resultado de la integral definida es:", resultado.evalf())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-5ce4d9700423> in <cell line: 19>()
#      17 # Paso 4: Calcular la integral resultante en términos de u
#      18 f_u = f.subs(x, sp.sqrt(u - 1)) * du_dx
# ---> 19 integral_u = sp.integrate(f_u, (u, a, b))
#      20
#      21 # Paso 5: Revertir el cambio de variable para obtener el resultado en términos de x
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/integrals.py in integrate(meijerg, conds, risch, heurisch, manual, *args, **kwargs)
#    1562         'manual': manual
#    1563         }
# -> 1564     integral = Integral(*args, **kwargs)
#    1565
#    1566     if isinstance(integral, Integral):
#
# /usr/local/lib/python3.10/dist-packages/sympy/integrals/integrals.py in __new__(cls, function, *symbols, **assumptions)
#      94                 active_deprecations_target="deprecated-integrate-poly")
#      95
# ---> 96         obj = AddWithLimits.__new__(cls, function, *symbols, **assumptions)
#      97         return obj
#      98
#
# /usr/local/lib/python3.10/dist-packages/sympy/concrete/expr_with_limits.py in __new__(cls, function, *symbols, **assumptions)
#     545     def __new__(cls, function, *symbols, **assumptions):
#     546         from sympy.concrete.summations import Sum
# --> 547         pre = _common_new(cls, function, *symbols,
#     548             discrete=issubclass(cls, Sum), **assumptions)
#     549         if isinstance(pre, tuple):
#
# /usr/local/lib/python3.10/dist-packages/sympy/concrete/expr_with_limits.py in _common_new(cls, function, discrete, *symbols, **assumptions)
#      55
#      56     if symbols:
# ---> 57         limits, orientation = _process_limits(*symbols, discrete=discrete)
#      58         for i, li in enumerate(limits):
#      59             if len(li) == 4:
#
# /usr/local/lib/python3.10/dist-packages/sympy/concrete/expr_with_limits.py in _process_limits(discrete, *symbols)
#     192                         continue
#     193
# --> 194         raise ValueError('Invalid limits given: %s' % str(symbols))
#     195
#     196     return limits, orientation
#
# ValueError: Invalid limits given: ((x**2 + 1, 1, 2),)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Función a integrar
def integrand(x):
    return x / (1 + x**2)**2

# Función para generar muestras aleatorias de x con distribución exponencial truncada
def generar_muestras(n):
    # Generar muestras de una distribución exponencial
    muestras_exp = np.random.exponential(scale=1, size=n)
    # Truncar las muestras para asegurarse de que estén en el rango [0, inf)
    muestras_truncadas = muestras_exp[muestras_exp > 0]
    return muestras_truncadas

# Función para calcular la integral aproximada utilizando Monte Carlo
def monte_carlo_integral(n):
    muestras = generar_muestras(n)
    integral_aproximada = np.mean(integrand(muestras))
    return integral_aproximada

# Repetir el experimento n veces
def experimento_monte_carlo(repeticiones, muestras_por_repeticion):
    resultados = []
    for _ in range(repeticiones):
        integral_aproximada = monte_carlo_integral(muestras_por_repeticion)
        resultados.append(integral_aproximada)
    return resultados

# Realizar el experimento Monte Carlo
repeticiones = 1000
muestras_por_repeticion = 1000
resultados_experimento = experimento_monte_carlo(repeticiones, muestras_por_repeticion)

# Calcular la probabilidad y su desviación estándar
probabilidad_media = np.mean(resultados_experimento)

# Imprimir el resultado de la integral
print("Resultado de la integral aproximado:", probabilidad_media)

# Gráfico de estabilización
plt.plot(resultados_experimento)
plt.xlabel('Experimento')
plt.ylabel('Integral Aproximada')
plt.title('Convergencia de la integral mediante Monte Carlo')
plt.show()

# Histograma de los resultados
plt.hist(resultados_experimento, bins=30, edgecolor='black')
plt.xlabel('Integral Aproximada')
plt.ylabel('Frecuencia')
plt.title('Histograma de resultados')
plt.show()
# Out:
# Resultado de la integral aproximado: 0.1892505287356616

# %%
import numpy as np
import matplotlib.pyplot as plt

# Función a integrar
def integrand(x):
    return x / (1 + x**2)**2

# Función para generar muestras aleatorias de x con distribución uniforme
def generar_muestras(n):
    muestras = np.random.uniform(0, 1, n)
    return muestras

# Función para calcular la integral analíticamente
def calcular_integral_analitica():
    return 0.5

# Función para calcular la integral aproximada utilizando Monte Carlo
def monte_carlo_integral(n):
    muestras = generar_muestras(n)
    integral_aproximada = np.mean(integrand(muestras))
    return integral_aproximada

# Repetir el experimento n veces
def experimento_monte_carlo(repeticiones, muestras_por_repeticion):
    resultados = []
    for _ in range(repeticiones):
        integral_aproximada = monte_carlo_integral(muestras_por_repeticion)
        resultados.append(integral_aproximada)
    return resultados

# Realizar el experimento Monte Carlo
repeticiones = 1000
muestras_por_repeticion = 1000
resultados_experimento = experimento_monte_carlo(repeticiones, muestras_por_repeticion)

# Calcular la probabilidad y su desviación estándar
probabilidad_media = np.mean(resultados_experimento)

# Calcular la integral analítica
integral_analitica = calcular_integral_analitica()

# Imprimir el resultado de la integral analítica y Monte Carlo
print("Resultado de la integral analítica:", integral_analitica)
print("Resultado de la integral aproximado (Monte Carlo):", probabilidad_media)

# Gráfico de estabilización
plt.plot(resultados_experimento)
plt.xlabel('Experimento')
plt.ylabel('Integral Aproximada')
plt.title('Convergencia de la integral mediante Monte Carlo')
plt.show()

# Histograma de los resultados
plt.hist(resultados_experimento, bins=30, edgecolor='black')
plt.xlabel('Integral Aproximada')
plt.ylabel('Frecuencia')
plt.title('Histograma de resultados')
plt.show()
# Out:
# Resultado de la integral analítica: 0.5
# Resultado de la integral aproximado (Monte Carlo): 0.2499158424507468
